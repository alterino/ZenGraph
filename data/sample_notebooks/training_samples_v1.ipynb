# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

N = np.random.randint(1,1000)
mean_0 = Q = np.random.randint(1, high=100)
std_0 = Q = np.random.randint(1, high=100)
x0 = np.random.normal(mean_0, std_0, N)

mean_1 = Q = np.random.randint(1, high=100)
std_1 = Q = np.random.randint(1, high=100)
x1 = np.random.normal(mean_1, std_1, N)

x2 = [np.random.randint(1,5) for _ in range(5)]

# %%
# Prompt: Write one line of python code that draws a histogram with 1 variable using matplotlib.pyplot.
# Code:
plt.hist(x0);###END###

# %%
# Prompt: Write one line of python code that draws a 2-d scatter plot using matplotlib.pyplot.
# Code:
plt.scatter(x0, x1);###END###

# %%
# Prompt: Write one line of python code that draws a line plot with 2 variables using matplotlib.pyplot and saves the returned object.
# Code:
plt.plot(x0, x1);###END###

# %%
# Prompt: Write one line of python code that draws a line plot with 2 variables using matplotlib.pyplot.
# Code:
h = plt.plot(x0, x1);###END###

# %%
# Prompt: Write one line of python code that draws a line plot with 2 variables using matplotlib.pyplot and saves the axes handle for customization.
# Code:
plt.plot(x0, x1);###END###

# %%
# Write one line of python code that reads the csv file 'input.csv' in as a pandas dataframe
# Code:
df0 = pd.read_csv('input.csv')###END###
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
cols = ['CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010']

# %%
# write python code that extracts the columns "cols" from a pandas dataframe.
# Code:
df1 = df0[cols]###END###

# %%
# Write one line of python code that plots two variables in a seaborn jointplot
# Code:
sns.jointplot(x=x0, y=x1);###END###

# %%
# Write one line of python code that plots two variables in a seaborn jointplot and saves the returned object for customization.
# Code:
h = sns.jointplot(x=x0, y=x1);###END###

# %%
# Write one line of matplotlib code that creates a box-and-whisker plot.
# Code:
plt.boxplot(x0);###END###

# %%
# Write one line of matplotlib code that creates a pie plot.
# Code:
plt.pie(x2);###END###

# %%
# Write one line of matplotlib code that sets the title of the active plot.
# Code:
plt.title('Here is the title');###END###

# %%
# Write one line of matplotlib code that rotates the xticks by N degrees.
# Code:
plt.xticks(rotation=N);###END###

# %%
# Write one line of matplotlib code that rotates the yticks by N degrees.
# Code:
plt.yticks(rotation=N);###END###

# %%
# Write one line of matplotlib code that makes the spines invisible for the axes with handle "ax".
# Code:
[ax.spines[side].set_visible(False) for side in ax.spines];###END###

# %%
# Write one line of python code that changes the facecolor of the axes "ax" with a medium gray tone.
# Code:
ax.set_facecolor('#DDDDDD')###END###
