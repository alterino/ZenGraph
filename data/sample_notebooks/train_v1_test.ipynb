# %%
'''-davinci-
###
Prompt:
###
Using the following input variables:
xdata = [3,4,6,2,1,3, 4, 7, 2, 3, 9]
ydata = ydata**3
---
and the following parameters:
title: "A title"
ylabel: "Some data"
xlabel: "Some other data"
legend: on
---
Write code that draws a simple line graph showing the input variables. Be sure to import the necessary
packages and initialize all necessary variables. Comment the code to show how you followed the instructions.

Code:

# importing necessary packages
import numpy as np
import matplotlib.pyplot as plt

# input data variables
xdata = [3,4,6,2,1,3, 4, 7, 2, 3, 9]
ydata = ydata**3

plt.figure()

# create line plot
plt.plot(xdata, '-o', ydata, '-o')

# set axes labels and title -- inferred from variable names --
# Set explicitly here or in prompt for more customized result.
plt.xlabel('Some data')
plt.ylabel('Some other data')
plt.title('A title')

# include a legend
plt.legend(['Baseline', 'Competition']);###END###
###
Prompt:
###
Using the following input variables:
baseline_data = np.array([1,2,3,4,5,6,7,8])
competition_data = baseline_data**2
---
and the following parameters:
title: "Baseline vs. Competition"
ylabel: "Baseline"
xlabel: "Competition"
legend: off
---
Write code that draws a simple line graph showing the input variables. Be sure to import the necessary
packages and initialize all necessary variables. Comment the code to show how you followed the instructions.

Code:'''

# Importing necessary packages
import numpy as np
import matplotlib.pyplot as plt

# Input data variables
baseline_data = np.array([1,2,3,4,5,6,7,8])
competition_data = baseline_data**2

plt.figure()

# Create line plot
plt.plot(baseline_data, '-o', competition_data, '-o')

# Set axes labels and title -- inferred from variable names --
# Set explicitly here or in prompt for more customized result.
plt.xlabel('Baseline')
plt.ylabel('Competition')
plt.title('Baseline vs. Competition')

# Include a legend
plt.legend(['Baseline', 'Competition'], loc='upper left');###END###

# %%
'''--curie--
###
Prompt:
###
Using the following input variables:
xdata = [3,4,6,2,1,3, 4, 7, 2, 3, 9]
ydata = ydata**3
---
and the following parameters:
title: "A title"
ylabel: "Some data"
xlabel: "Some other data"
legend: on
---
Write code that draws a simple line graph showing the input variables. Be sure to import the necessary
packages and initialize all necessary variables. Comment the code to show how you followed the instructions.

Code:

# importing necessary packages
import numpy as np
import matplotlib.pyplot as plt

# input data variables
xdata = [3,4,6,2,1,3, 4, 7, 2, 3, 9]
ydata = ydata**3

plt.figure()

# create line plot
plt.plot(xdata, '-o', ydata, '-o')

# set axes labels and title -- inferred from variable names --
# Set explicitly here or in prompt for more customized result.
plt.xlabel('Some data')
plt.ylabel('Some other data')
plt.title('A title')

# include a legend
plt.legend(['Baseline', 'Competition']);###END###
###
Prompt:
###
Using the following input variables:
baseline_data = np.array([1,2,3,4,5,6,7,8])
competition_data = baseline_data**2
---
and the following parameters:
title: "Baseline vs. Competition"
ylabel: "Baseline"
xlabel: "Competition"
legend: off
---
Write code that draws a simple line graph showing the input variables. Be sure to import the necessary
packages and initialize all necessary variables. Comment the code to show how you followed the instructions.

Code:'''

# importing necessary packages
import numpy as np
import matplotlib.pyplot as plt

# input data variables
baseline_data = np.array([1,2,3,4,5,6,7,8])
competition_data = baseline_data**2

plt.figure()

# create line plot
plt.plot(baseline_data, '-o', competition_data, '-o')

# set axes labels and title -- inferred from variable names --
# Set explicitly here or in prompt for more customized result.
plt.xlabel('Baseline')
plt.ylabel('Competition')
plt.title('Baseline vs. Competition')

# include a legend
plt.legend(['Baseline', 'Competition'])

# %%
'''--babbage--
Prompt:
###
Using the following input variables:
xdata = [3,4,6,2,1,3, 4, 7, 2, 3, 9]
ydata = xdata**3
---
and the following parameters:
title: "A title"
ylabel: "Some data"
xlabel: "Some other data"
legend: on
---
Write code that draws a simple line graph showing the input variables. Be sure to import the necessary
packages and initialize all necessary variables. Comment the code to show how you followed the instructions.

Code:

# importing necessary packages
import numpy as np
import matplotlib.pyplot as plt

# input data variables
xdata = [3,4,6,2,1,3, 4, 7, 2, 3, 9]
ydata = ydata**3

plt.figure()

# create line plot
plt.plot(xdata, '-o', ydata, '-o')

# set axes labels and title -- inferred from variable names --
# Set explicitly here or in prompt for more customized result.
plt.xlabel('Some data')
plt.ylabel('Some other data')
plt.title('A title')

# include a legend
plt.legend(['Baseline', 'Competition']);###END###
Prompt:
###
Using the following input variables:
baseline_data = np.array([1,2,3,4,5,6,7,8])
competition_data = baseline_data**2
---
and the following parameters:
title: "Baseline vs. Competition"
ylabel: "Baseline"
xlabel: "Competition"
legend: off
---
Write code that draws a simple line graph showing the input variables. Be sure to import the necessary
packages and initialize all necessary variables. Comment the code to show how you followed the instructions.

Code:'''

# importing necessary packages
import numpy as np
import matplotlib.pyplot as plt

# input data variables
xdata = [3,4,6,2,1,3, 4, 7, 2, 3, 9]
ydata = ydata**3

plt.figure()

# create line plot
plt.plot(xdata, '-o', ydata, '-o')

# set axes labels and title -- inferred from variable names --
# Set explicitly here or in prompt for more customized result.
plt.xlabel('Some data')
plt.ylabel('Some other data')
# include a legend
plt.legend(['Baseline', 'Competition']);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-879722861bbb> in <module>
#      61 # input data variables
#      62 xdata = [3,4,6,2,1,3, 4, 7, 2, 3, 9]
# ---> 63 ydata = ydata**3
#      64
#      65 plt.figure()
#
# NameError: name 'ydata' is not defined

# %%
'''-davinci-
###
Prompt:
###
Using the following input variables:
xdata = [3,4,6,2,1,3, 4, 7, 2, 3, 9]
ydata = ydata**3
---
and the following parameters:
title: "A title"
ylabel: "Some data"
xlabel: "Some other data"
legend: on
---
Write code that draws a simple line graph showing the input variables. Be sure to import the necessary
packages and initialize all necessary variables. Comment the code to show how you followed the instructions. Include a legend.

Code:

# importing necessary packages
import numpy as np
import matplotlib.pyplot as plt

# input data variables
xdata = [3,4,6,2,1,3, 4, 7, 2, 3, 9]
ydata = ydata**3

plt.figure()

# create line plot
plt.plot(xdata, '-o', ydata, '-o')

# set axes labels and title -- inferred from variable names --
# Set explicitly here or in prompt for more customized result.
plt.xlabel('Some data')
plt.ylabel('Some other data')
plt.title('A title')

# include a legend
plt.legend(['Baseline', 'Competition']);###END###
###
Prompt:
###
Using the following input variables:
baseline_data = np.array([1,2,3,4,5,6,7,8])
competition_data = baseline_data**2
---
and the following parameters:
title: "Baseline vs. Competition"
ylabel: "Baseline"
xlabel: "Competition"
legend: off
---
Write code that draws a simple line graph showing the input variables. Be sure to import the necessary
packages and initialize all necessary variables. Comment the code to show how you followed the instructions. Do not include a legend.

Code:'''

# importing necessary packages
import numpy as np
import matplotlib.pyplot as plt

# input data variables
baseline_data = np.array([1,2,3,4,5,6,7,8])
competition_data = baseline_data**2

plt.figure()

# create line plot
plt.plot(baseline_data, '-o', competition_data, '-o')

# set axes labels and title -- inferred from variable names --
# Set explicitly here or in prompt for more customized result.
plt.xlabel('Baseline')
plt.ylabel('Competition')
plt.title('Baseline vs. Competition')

# do not include a legend
# Out:
# Text(0.5, 1.0, 'Baseline vs. Competition')

# %%
#davinci
'''
Prompt:
Using the following input variables:
v1 = pd.Series(np.random.normal(0,10,1000), name='v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000), name='v2')
---
and the following parameters:
labels: off
bins: np.arange(-50,150,5)
---
Write code that draws a simple histogram of the input data. Make sure it is fully functional.
Comment the code to show how you followed the instructions.

Code:
# import packages so it is fully functional code
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# set inputs as specified
v1 = pd.Series(np.random.normal(0,10,1000), name='v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000), name='v2')

plt.figure()
plt.hist(v1, bins=np.arange(-50,150,5), label='v1');
plt.hist(v2, bins=np.arange(-50,150,5), label='v2');
plt.legend();###END###
Prompt:
Using the following input variables:
seriesA = pd.Series(np.random.normal(0,10,1000), name='A')
seriesB = pd.Series(2*seriesA+ np.random.normal(60,15,1000), name='B')
---
and the following parameters:
labels: off
bins: 20
---
Write code that draws a simple histogram of the input data. Make sure it is fully functional. Comment the code to show how you followed the instructions.

Code:'''
# import packages so it is fully functional code
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# set inputs as specified
seriesA = pd.Series(np.random.normal(0,10,1000), name='A')
seriesB = pd.Series(2*seriesA + np.random.normal(60,15,1000), name='B')

plt.figure()
plt.hist(seriesA, bins=20, label='A');
plt.hist(seriesB, bins=20, label='B');
plt.legend();

# %%
#curie
'''
Prompt:
Using the following input variables:
v1 = pd.Series(np.random.normal(0,10,1000), name='v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000), name='v2')
---
and the following parameters:
labels: off
bins: np.arange(-50,150,5)
---
Write code that draws a simple histogram of the input data. Make sure it is fully functional.
Comment the code to show how you followed the instructions.

Code:
# import packages so it is fully functional code
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# set inputs as specified
v1 = pd.Series(np.random.normal(0,10,1000), name='v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000), name='v2')

plt.figure()
plt.hist(v1, bins=np.arange(-50,150,5), label='v1');
plt.hist(v2, bins=np.arange(-50,150,5), label='v2');
plt.legend();###END###
Prompt:
Using the following input variables:
seriesA = pd.Series(np.random.normal(0,10,1000), name='A')
seriesB = pd.Series(2*seriesA+ np.random.normal(60,15,1000), name='B')
---
and the following parameters:
labels: off
bins: 20
---
Write code that draws a simple histogram of the input data. Make sure it is fully functional. Comment the code to show how you followed the instructions.

Code:'''
# import packages so it is fully functional code
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# set inputs as specified
seriesA = pd.Series(np.random.normal(0,10,1000), name='A')
seriesB = pd.Series(2*seriesA+ np.random.normal(60,15,1000), name='B')

plt.figure()
plt.hist(seriesA, bins=20, label='A');
plt.hist(seriesB, bins=20, label='B');
plt.legend();

# %%
#curie
'''Prompt:
Using the following input variables:
input from csv: 'intput/genericinput.csv'
---
Write code that reads data into a pandas dataframe and draws two side-by-side histograms
of 'generic' data for entries whose 'columnname' is either 'val0' or 'val1'. Make sure the code is
fully functional. Comment to show what you're doing.

Code:
# import necessary packages
import pandas as pd

# import data from specified file
df = pd.read_csv('intput/genericinput.csv')
# extract relevant columns
df = df[df['columnname'].isin(['val0, 'val1'])]

# plot a histogram
df['generic'].hist(by=df['columnname'], bins=20);###END###
Prompt:
Using the following input variables:
input from csv: 'datasets/house_prices.csv'
---
Write code that reads data into a pandas dataframe and fraws two side-by-side histograms
of 'price' data for entries whose 'type' is either 'Residential' or 'Condo'. Make sure the code is
fully functional. Comment to show what you're doing.

Code:'''
# import necessary packages
import pandas as pd

# import data from specified file
df = pd.read_csv('datasets/house_prices.csv')

# extract relevant columns
df = df[df['type'].isin(['Residential'], 'Condo'])]

# plot a histogram
df['price'].hist(by=df['type'], bins=20);

# %%
#curie (second try)
'''Code:
# import necessary packages
import pandas as pd

# import data from specified file
df = pd.read_csv('intput/genericinput.csv')
# extract relevant columns
df = df[df['columnname'].isin(['val0, 'val1'])])

# plot a histogram
df['generic'].hist(by=df['columnname'], bins=20);###END###
Prompt:
Using the following input variables:
input from csv: 'datasets/house_prices.csv'
---
Write code that reads data into a pandas dataframe and fraws two side-by-side histograms
of 'price' data for entries whose 'type' is either 'Residential' or 'Condo'. Make sure the code is
fully functional. Comment to show what you're doing.

Code:'''
# import necessary packages
import pandas as pd

# import data from specified file
df = pd.read_csv('datasets/house_prices.csv')
# extract relevant columns
df = df[df['type'].isin(['Residential', 'Condo'])]

# plot a histogram
df['price'].hist(by=df['type'], bins=20);
